# %% [markdown]
# # Fine-Tune Whisper For Multilingual ASR with 🤗 Transformers

# %% [markdown]
# In this Colab, we present a step-by-step guide on how to fine-tune Whisper
# for any multilingual ASR dataset using Hugging Face 🤗 Transformers. This is a
# more "hands-on" version of the accompanying [blog post](https://huggingface.co/blog/fine-tune-whisper).
# For a more in-depth explanation of Whisper, the Common Voice dataset and the theory behind fine-tuning, the reader is advised to refer to the blog post.

# %% [markdown]
# ## Introduction

# %% [markdown]
# Whisper is a pre-trained model for automatic speech recognition (ASR)
# published in [September 2022](https://openai.com/blog/whisper/) by the authors
# Alec Radford et al. from OpenAI. Unlike many of its predecessors, such as
# [Wav2Vec 2.0](https://arxiv.org/abs/2006.11477), which are pre-trained
# on un-labelled audio data, Whisper is pre-trained on a vast quantity of
# **labelled** audio-transcription data, 680,000 hours to be precise.
# This is an order of magnitude more data than the un-labelled audio data used
# to train Wav2Vec 2.0 (60,000 hours). What is more, 117,000 hours of this
# pre-training data is multilingual ASR data. This results in checkpoints
# that can be applied to over 96 languages, many of which are considered
# _low-resource_.
#
# When scaled to 680,000 hours of labelled pre-training data, Whisper models
# demonstrate a strong ability to generalise to many datasets and domains.
# The pre-trained checkpoints achieve competitive results to state-of-the-art
# ASR systems, with near 3% word error rate (WER) on the test-clean subset of
# LibriSpeech ASR and a new state-of-the-art on TED-LIUM with 4.7% WER (_c.f._
# Table 8 of the [Whisper paper](https://cdn.openai.com/papers/whisper.pdf)).
# The extensive multilingual ASR knowledge acquired by Whisper during pre-training
# can be leveraged for other low-resource languages; through fine-tuning, the
# pre-trained checkpoints can be adapted for specific datasets and languages
# to further improve upon these results. We'll show just how Whisper can be fine-tuned
# for low-resource languages in this Colab.

# %% [markdown]
# <figure>
# <img src="https://raw.githubusercontent.com/sanchit-gandhi/notebooks/main/whisper_architecture.svg" alt="Trulli" style="width:100%">
# <figcaption align = "center"><b>Figure 1:</b> Whisper model. The architecture
# follows the standard Transformer-based encoder-decoder model. A
# log-Mel spectrogram is input to the encoder. The last encoder
# hidden states are input to the decoder via cross-attention mechanisms. The
# decoder autoregressively predicts text tokens, jointly conditional on the
# encoder hidden states and previously predicted tokens. Figure source:
# <a href="https://openai.com/blog/whisper/">OpenAI Whisper Blog</a>.</figcaption>
# </figure>

# %% [markdown]
# The Whisper checkpoints come in five configurations of varying model sizes.
# The smallest four are trained on either English-only or multilingual data.
# The largest checkpoint is multilingual only. All nine of the pre-trained checkpoints
# are available on the [Hugging Face Hub](https://huggingface.co/models?search=openai/whisper). The
# checkpoints are summarised in the following table with links to the models on the Hub:
#
# | Size   | Layers | Width | Heads | Parameters | English-only                                         | Multilingual                                      |
# |--------|--------|-------|-------|------------|------------------------------------------------------|---------------------------------------------------|
# | tiny   | 4      | 384   | 6     | 39 M       | [✓](https://huggingface.co/openai/whisper-tiny.en)   | [✓](https://huggingface.co/openai/whisper-tiny.)  |
# | base   | 6      | 512   | 8     | 74 M       | [✓](https://huggingface.co/openai/whisper-base.en)   | [✓](https://huggingface.co/openai/whisper-base)   |
# | small  | 12     | 768   | 12    | 244 M      | [✓](https://huggingface.co/openai/whisper-small.en)  | [✓](https://huggingface.co/openai/whisper-small)  |
# | medium | 24     | 1024  | 16    | 769 M      | [✓](https://huggingface.co/openai/whisper-medium.en) | [✓](https://huggingface.co/openai/whisper-medium) |
# | large  | 32     | 1280  | 20    | 1550 M     | x                                                    | [✓](https://huggingface.co/openai/whisper-large)  |
#
# For demonstration purposes, we'll fine-tune the multilingual version of the
# [`"small"`](https://huggingface.co/openai/whisper-small) checkpoint with 244M params (~= 1GB).
# As for our data, we'll train and evaluate our system on a low-resource language
# taken from the [Common Voice](https://huggingface.co/datasets/mozilla-foundation/common_voice_11_0)
# dataset. We'll show that with as little as 8 hours of fine-tuning data, we can achieve
# strong performance in this language.

# %% [markdown]
# ------------------------------------------------------------------------
#
# \\({}^1\\) The name Whisper follows from the acronym “WSPSR”, which stands for “Web-scale Supervised Pre-training for Speech Recognition”.

# %% [markdown]
# ## Prepare Environment

# %% [markdown]
# First of all, let's try to secure a decent GPU for our Colab! Unfortunately, it's becoming much harder to get access to a good GPU with the free version of Google Colab. However, with Google Colab Pro one should have no issues in being allocated a V100 or P100 GPU.
#
# To get a GPU, click _Runtime_ -> _Change runtime type_, then change _Hardware accelerator_ from _None_ to _GPU_.

# %% [markdown]
# We can verify that we've been assigned a GPU and view its specifications:

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# zsh:1: command not found: nvidia-smi

# %% [markdown]
# Next, we need to update the Unix package `ffmpeg` to version 4:

# %%
# !add-apt-repository -y ppa:jonathonf/ffmpeg-4
# !apt update
# !apt install -y ffmpeg
# Out:
# zsh:1: command not found: add-apt-repository
# The operation couldn’t be completed. Unable to locate a Java Runtime that supports apt.
# Please visit http://www.java.com for information on installing Java.
#
# The operation couldn’t be completed. Unable to locate a Java Runtime that supports apt.
# Please visit http://www.java.com for information on installing Java.

# %% [markdown]
# We'll employ several popular Python packages to fine-tune the Whisper model.
# We'll use `datasets` to download and prepare our training data and
# `transformers` to load and train our Whisper model. We'll also require
# the `soundfile` package to pre-process audio files, `evaluate` and `jiwer` to
# assess the performance of our model. Finally, we'll
# use `gradio` to build a flashy demo of our fine-tuned model.

# %%
# !pip install datasets>=2.6.1
# !pip install librosa
# !pip install evaluate>=0.30
# !pip install jiwer
# !pip install gradio
# !pip install hopsworks
! pip install -U accelerate
! pip install -U transformers
! pip install chardet
# Out:
# zsh:1: 2.6.1 not found
# Requirement already satisfied: librosa in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from librosa) (1.26.0)
# Requirement already satisfied: scipy>=1.2.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from librosa) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from librosa) (1.1.1)
# Requirement already satisfied: joblib>=0.14 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from librosa) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from librosa) (4.8.0)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pooch>=1.0->librosa) (3.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pooch>=1.0->librosa) (23.2)
# Requirement already satisfied: requests>=2.19.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.11.17)
# zsh:1: 0.30 not found
# Requirement already satisfied: jiwer in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (3.0.3)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from jiwer) (8.1.7)
# Requirement already satisfied: rapidfuzz<4,>=3 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from jiwer) (3.5.2)
# Requirement already satisfied: gradio in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (3.14.0)
# Requirement already satisfied: aiohttp in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (3.8.5)
# Requirement already satisfied: altair in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (4.2.2)
# Requirement already satisfied: fastapi in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (0.104.1)
# Requirement already satisfied: ffmpy in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (0.3.1)
# Requirement already satisfied: fsspec in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (2023.10.0)
# Requirement already satisfied: httpx in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: jinja2 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (3.0.3)
# Requirement already satisfied: markdown-it-py[linkify,plugins] in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (3.0.0)
# Requirement already satisfied: markupsafe in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (2.0.1)
# Requirement already satisfied: matplotlib in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (3.8.1)
# Requirement already satisfied: numpy in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (1.26.0)
# Requirement already satisfied: orjson in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (3.9.10)
# Requirement already satisfied: pandas in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (2.0.3)
# Requirement already satisfied: pillow in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (10.1.0)
# Requirement already satisfied: pycryptodome in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (3.19.0)
# Requirement already satisfied: pydantic in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (2.4.2)
# Requirement already satisfied: pydub in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pyyaml in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: requests in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (2.31.0)
# Requirement already satisfied: uvicorn in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (0.24.0.post1)
# Requirement already satisfied: websockets>=10.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from gradio) (12.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from aiohttp->gradio) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from aiohttp->gradio) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from aiohttp->gradio) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from aiohttp->gradio) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from aiohttp->gradio) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from aiohttp->gradio) (1.2.0)
# Requirement already satisfied: entrypoints in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from altair->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from altair->gradio) (4.19.2)
# Requirement already satisfied: toolz in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from altair->gradio) (0.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pandas->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pandas->gradio) (2023.3)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from fastapi->gradio) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from fastapi->gradio) (4.8.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pydantic->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pydantic->gradio) (2.10.1)
# Requirement already satisfied: certifi in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from httpx->gradio) (2023.11.17)
# Requirement already satisfied: httpcore in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from httpx->gradio) (1.0.1)
# Requirement already satisfied: idna in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from httpx->gradio) (3.4)
# Requirement already satisfied: sniffio in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]->gradio) (2.0.2)
# Requirement already satisfied: mdit-py-plugins in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]->gradio) (0.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from matplotlib->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from matplotlib->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from matplotlib->gradio) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from matplotlib->gradio) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from matplotlib->gradio) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from matplotlib->gradio) (2.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests->gradio) (1.26.18)
# Requirement already satisfied: click>=7.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from uvicorn->gradio) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from uvicorn->gradio) (0.14.0)
# Requirement already satisfied: exceptiongroup in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio) (1.1.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from jsonschema>=3.0->altair->gradio) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from jsonschema>=3.0->altair->gradio) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from jsonschema>=3.0->altair->gradio) (0.12.0)
# Requirement already satisfied: uc-micro-py in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]->gradio) (1.0.2)
# Requirement already satisfied: six>=1.5 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->gradio) (1.16.0)
# Requirement already satisfied: hopsworks in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (3.4.3)
# Requirement already satisfied: hsfs<3.5.0,>=3.4.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs[python]<3.5.0,>=3.4.0->hopsworks) (3.4.4)
# Requirement already satisfied: hsml<3.5.0,>=3.4.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hopsworks) (3.4.3)
# Requirement already satisfied: pyhumps==1.6.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hopsworks) (1.6.1)
# Requirement already satisfied: requests in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hopsworks) (2.31.0)
# Requirement already satisfied: furl in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hopsworks) (2.1.3)
# Requirement already satisfied: boto3 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hopsworks) (1.28.80)
# Requirement already satisfied: pyjks in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hopsworks) (20.0.0)
# Requirement already satisfied: mock in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hopsworks) (5.1.0)
# Requirement already satisfied: tqdm in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hopsworks) (4.65.0)
# Requirement already satisfied: pandas<2.1.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2.0.3)
# Requirement already satisfied: numpy in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (1.26.0)
# Requirement already satisfied: avro==1.11.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (1.11.0)
# Requirement already satisfied: sqlalchemy in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2.0.23)
# Requirement already satisfied: PyMySQL[rsa] in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (1.1.0)
# Requirement already satisfied: great-expectations==0.14.13 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.14.13)
# Requirement already satisfied: markupsafe<2.1.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2.0.1)
# Requirement already satisfied: tzlocal in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (5.2)
# Requirement already satisfied: fsspec in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2023.10.0)
# Requirement already satisfied: altair<5,>=4.0.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (4.2.2)
# Requirement already satisfied: Click>=7.1.2 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (8.1.7)
# Requirement already satisfied: colorama>=0.4.3 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.4.6)
# Requirement already satisfied: cryptography>=3.2 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (41.0.3)
# Requirement already satisfied: dataclasses in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.6)
# Requirement already satisfied: importlib-metadata>=1.7.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (6.8.0)
# Requirement already satisfied: Ipython>=7.16.3 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (8.17.2)
# Requirement already satisfied: jinja2<3.1.0,>=2.10 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (3.0.3)
# Requirement already satisfied: jsonpatch>=1.22 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (1.33)
# Requirement already satisfied: jsonschema>=2.5.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (4.19.2)
# Requirement already satisfied: mistune>=0.8.4 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (3.0.2)
# Requirement already satisfied: nbformat>=5.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (5.9.2)
# Requirement already satisfied: packaging in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (23.2)
# Requirement already satisfied: pyparsing<3,>=2.4 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2.8.2)
# Requirement already satisfied: pytz>=2021.3 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2023.3.post1)
# Requirement already satisfied: ruamel.yaml<0.17.18,>=0.16 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.17.17)
# Requirement already satisfied: scipy>=0.19.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (1.11.3)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (4.8.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (1.26.18)
# Requirement already satisfied: pyhopshive[thrift] in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.6.4.1.dev0)
# Requirement already satisfied: pyarrow>=10.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs[python]<3.5.0,>=3.4.0->hopsworks) (11.0.0)
# Requirement already satisfied: confluent-kafka<=2.1.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2.1.1)
# Requirement already satisfied: fastavro<=1.8.2,>=1.4.11 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from hsfs[python]<3.5.0,>=3.4.0->hopsworks) (1.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests->hopsworks) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests->hopsworks) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests->hopsworks) (2023.11.17)
# Requirement already satisfied: botocore<1.32.0,>=1.31.80 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from boto3->hopsworks) (1.31.80)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from boto3->hopsworks) (1.0.1)
# Requirement already satisfied: s3transfer<0.8.0,>=0.7.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from boto3->hopsworks) (0.7.0)
# Requirement already satisfied: six>=1.8.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from furl->hopsworks) (1.16.0)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from furl->hopsworks) (1.0.1)
# Requirement already satisfied: javaobj-py3 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pyjks->hopsworks) (0.4.3)
# Requirement already satisfied: pyasn1>=0.3.5 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pyjks->hopsworks) (0.5.0)
# Requirement already satisfied: pyasn1-modules in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pyjks->hopsworks) (0.3.0)
# Requirement already satisfied: pycryptodomex in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pyjks->hopsworks) (3.19.0)
# Requirement already satisfied: twofish in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pyjks->hopsworks) (0.3.0)
# Requirement already satisfied: tzdata>=2022.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pandas<2.1.0->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2023.3)
# Requirement already satisfied: future in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pyhopshive[thrift]; extra == "python"->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.18.3)
# Requirement already satisfied: thrift>=0.10.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pyhopshive[thrift]; extra == "python"->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.16.0)
# Requirement already satisfied: entrypoints in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from altair<5,>=4.0.0->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.4)
# Requirement already satisfied: toolz in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from altair<5,>=4.0.0->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.12.0)
# Requirement already satisfied: cffi>=1.12 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from cryptography>=3.2->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from importlib-metadata>=1.7.0->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (3.17.0)
# Requirement already satisfied: decorator in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2.16.1)
# Requirement already satisfied: stack-data in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (5.13.0)
# Requirement already satisfied: exceptiongroup in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (4.8.0)
# Requirement already satisfied: appnope in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from jsonpatch>=1.22->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2.4)
# Requirement already satisfied: attrs>=22.2.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from jsonschema>=2.5.1->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from jsonschema>=2.5.1->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from jsonschema>=2.5.1->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from jsonschema>=2.5.1->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.12.0)
# Requirement already satisfied: fastjsonschema in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from nbformat>=5.0->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2.18.1)
# Requirement already satisfied: jupyter-core in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from nbformat>=5.0->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (5.5.0)
# Requirement already satisfied: pycparser in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.2->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from jedi>=0.16->Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from pexpect>4.3->Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.2.9)
# Requirement already satisfied: platformdirs>=2.5 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from jupyter-core->nbformat>=5.0->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (3.11.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great-expectations==0.14.13->hsfs<3.5.0,>=3.4.0->hsfs[python]<3.5.0,>=3.4.0->hopsworks) (0.2.2)
# Requirement already satisfied: accelerate in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (0.25.0)
# Requirement already satisfied: numpy>=1.17 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from accelerate) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from accelerate) (2.1.1)
# Requirement already satisfied: huggingface-hub in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from accelerate) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from accelerate) (0.4.0)
# Requirement already satisfied: filelock in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (4.8.0)
# Requirement already satisfied: sympy in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.0.3)
# Requirement already satisfied: fsspec in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2023.10.0)
# Requirement already satisfied: requests in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from huggingface-hub->accelerate) (4.65.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: transformers in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (4.36.0.dev0)
# Requirement already satisfied: filelock in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from transformers) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages (from requests->transformers) (2023.11.17)
# Collecting chardet
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 14.9 MB/s eta 0:00:00
# Installing collected packages: chardet
# Successfully installed chardet-5.2.0

# %% [markdown]
# We strongly advise you to upload model checkpoints directly the [Hugging Face Hub](https://huggingface.co/)
# whilst training. The Hub provides:
# - Integrated version control: you can be sure that no model checkpoint is lost during training.
# - Tensorboard logs: track important metrics over the course of training.
# - Model cards: document what a model does and its intended use cases.
# - Community: an easy way to share and collaborate with the community!
#
# Linking the notebook to the Hub is straightforward - it simply requires entering your
# Hub authentication token when prompted. Find your Hub authentication token [here](https://huggingface.co/settings/tokens):

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/requests/compat.py:11
#      10 try:
# ---> 11     import chardet
#      12 except ImportError:
#
# ModuleNotFoundError: No module named 'chardet'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from huggingface_hub import notebook_login
#       3 notebook_login()
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/huggingface_hub/__init__.py:357, in _attach.<locals>.__getattr__(name)
#     355 elif name in attr_to_modules:
#     356     submod_path = f"{package_name}.{attr_to_modules[name]}"
# --> 357     submod = importlib.import_module(submod_path)
#     358     attr = getattr(submod, name)
#     360     # If the attribute lives in a file (module) with the same
#     361     # name as the attribute, ensure that the attribute and *not*
#     362     # the module is accessible on the package.
#
# File ~/miniforge3/envs/scalable/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/huggingface_hub/_login.py:22
#      19 from typing import Optional
#      21 from .commands._cli_utils import ANSI
# ---> 22 from .commands.delete_cache import _ask_for_confirmation_no_tui
#      23 from .hf_api import get_token_permission
#      24 from .utils import (
#      25     HfFolder,
#      26     capture_output,
#    (...)
#      33     unset_git_credential,
#      34 )
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/huggingface_hub/commands/delete_cache.py:64
#      61 from tempfile import mkstemp
#      62 from typing import Any, Callable, Iterable, List, Optional, Union
# ---> 64 from ..utils import CachedRepoInfo, CachedRevisionInfo, HFCacheInfo, scan_cache_dir
#      65 from . import BaseHuggingfaceCLICommand
#      66 from ._cli_utils import ANSI
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/huggingface_hub/utils/__init__.py:32
#      30 from ._chunk_utils import chunk_iterable
#      31 from ._datetime import parse_datetime
# ---> 32 from ._errors import (
#      33     BadRequestError,
#      34     EntryNotFoundError,
#      35     FileMetadataError,
#      36     GatedRepoError,
#      37     HfHubHTTPError,
#      38     LocalEntryNotFoundError,
#      39     RepositoryNotFoundError,
#      40     RevisionNotFoundError,
#      41     hf_raise_for_status,
#      42 )
#      43 from ._fixes import SoftTemporaryDirectory, yaml_dump
#      44 from ._git_credential import list_credential_helpers, set_git_credential, unset_git_credential
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:3
#       1 from typing import Optional
# ----> 3 from requests import HTTPError, Response
#       5 from ..constants import INFERENCE_ENDPOINTS_ENDPOINT
#       6 from ._fixes import JSONDecodeError
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/requests/__init__.py:45
#      41 import warnings
#      43 import urllib3
# ---> 45 from .exceptions import RequestsDependencyWarning
#      47 try:
#      48     from charset_normalizer import __version__ as charset_normalizer_version
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/requests/exceptions.py:9
#       1 """
#       2 requests.exceptions
#       3 ~~~~~~~~~~~~~~~~~~~
#       4
#       5 This module contains the set of Requests' exceptions.
#       6 """
#       7 from urllib3.exceptions import HTTPError as BaseHTTPError
# ----> 9 from .compat import JSONDecodeError as CompatJSONDecodeError
#      12 class RequestException(IOError):
#      13     """There was an ambiguous exception that occurred while handling your
#      14     request.
#      15     """
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/requests/compat.py:13
#      11     import chardet
#      12 except ImportError:
# ---> 13     import charset_normalizer as chardet
#      15 import sys
#      17 # -------
#      18 # Pythons
#      19 # -------
#      20
#      21 # Syntax sugar.
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/charset_normalizer/__init__.py:23
#       1 """
#       2 Charset-Normalizer
#       3 ~~~~~~~~~~~~~~
#    (...)
#      21 :license: MIT, see LICENSE for more details.
#      22 """
# ---> 23 from charset_normalizer.api import from_fp, from_path, from_bytes, normalize
#      24 from charset_normalizer.legacy import detect
#      25 from charset_normalizer.version import __version__, VERSION
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/charset_normalizer/api.py:10
#       7     PathLike = Union[str, 'os.PathLike[str]']  # type: ignore
#       9 from charset_normalizer.constant import TOO_SMALL_SEQUENCE, TOO_BIG_SEQUENCE, IANA_SUPPORTED
# ---> 10 from charset_normalizer.md import mess_ratio
#      11 from charset_normalizer.models import CharsetMatches, CharsetMatch
#      12 from warnings import warn
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/charset_normalizer/md.py:5
#       2 from typing import Optional, List
#       4 from charset_normalizer.constant import UNICODE_SECONDARY_RANGE_KEYWORD
# ----> 5 from charset_normalizer.utils import is_punctuation, is_symbol, unicode_range, is_accentuated, is_latin, \
#       6     remove_accent, is_separator, is_cjk, is_case_variable, is_hangul, is_katakana, is_hiragana, is_ascii, is_thai
#       9 class MessDetectorPlugin:
#      10     """
#      11     Base abstract class used for mess detection plugins.
#      12     All detectors MUST extend and implement given methods.
#      13     """
#
# ImportError: cannot import name 'COMMON_SAFE_ASCII_CHARACTERS' from 'charset_normalizer.constant' (/Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages/charset_normalizer/constant.py)

# %%
import hopsworks
project = hopsworks.login()
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/193684

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# Using 🤗 Datasets, downloading and preparing data is extremely simple.
# We can download and prepare the Common Voice splits in just one line of code.
#
# First, ensure you have accepted the terms of use on the Hugging Face Hub: [mozilla-foundation/common_voice_11_0](https://huggingface.co/datasets/mozilla-foundation/common_voice_11_0). Once you have accepted the terms, you will have full access to the dataset and be able to download the data locally.
#
# Since Hindi is very low-resource, we'll combine the `train` and `validation`
# splits to give approximately 8 hours of training data. We'll use the 4 hours
# of `test` data as our held-out test set:

# %%
from datasets import load_dataset, DatasetDict

common_voice = DatasetDict()

common_voice["train"] = load_dataset("mozilla-foundation/common_voice_11_0", "it", split="train[:10%]", use_auth_token=True)
common_voice["test"] = load_dataset("mozilla-foundation/common_voice_11_0", "it", split="test[:10%]", use_auth_token=True)

print(common_voice)
# Out:
# FutureWarning: 'use_auth_token' was deprecated in favor of 'token' in version 2.14.0 and will be removed in 3.0.0.
# You can remove this warning by passing 'token=<use_auth_token>' instead.
# DatasetDict({
#     train: Dataset({
#         features: ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment'],
#         num_rows: 15261
#     })
#     test: Dataset({
#         features: ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment'],
#         num_rows: 1500
#     })
# })

# %% [markdown]
# Most ASR datasets only provide input audio samples (`audio`) and the
# corresponding transcribed text (`sentence`). Common Voice contains additional
# metadata information, such as `accent` and `locale`, which we can disregard for ASR.
# Keeping the notebook as general as possible, we only consider the input audio and
# transcribed text for fine-tuning, discarding the additional metadata information:

# %%
common_voice = common_voice.remove_columns(["accent", "age", "client_id", "down_votes", "gender", "locale", "path", "segment", "up_votes"])

print(common_voice)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'sentence'],
#         num_rows: 15261
#     })
#     test: Dataset({
#         features: ['audio', 'sentence'],
#         num_rows: 1500
#     })
# })

# %% [markdown]
# ## Prepare Feature Extractor, Tokenizer and Data

# %% [markdown]
# The ASR pipeline can be de-composed into three stages:
# 1) A feature extractor which pre-processes the raw audio-inputs
# 2) The model which performs the sequence-to-sequence mapping
# 3) A tokenizer which post-processes the model outputs to text format
#
# In 🤗 Transformers, the Whisper model has an associated feature extractor and tokenizer,
# called [WhisperFeatureExtractor](https://huggingface.co/docs/transformers/main/model_doc/whisper#transformers.WhisperFeatureExtractor)
# and [WhisperTokenizer](https://huggingface.co/docs/transformers/main/model_doc/whisper#transformers.WhisperTokenizer)
# respectively.
#
# We'll go through details for setting-up the feature extractor and tokenizer one-by-one!

# %% [markdown]
# ### Load WhisperFeatureExtractor

# %% [markdown]
# The Whisper feature extractor performs two operations:
# 1. Pads / truncates the audio inputs to 30s: any audio inputs shorter than 30s are padded to 30s with silence (zeros), and those longer that 30s are truncated to 30s
# 2. Converts the audio inputs to _log-Mel spectrogram_ input features, a visual representation of the audio and the form of the input expected by the Whisper model

# %% [markdown]
# <figure>
# <img src="https://raw.githubusercontent.com/sanchit-gandhi/notebooks/main/spectrogram.jpg" alt="Trulli" style="width:100%">
# <figcaption align = "center"><b>Figure 2:</b> Conversion of sampled audio array to log-Mel spectrogram.
# Left: sampled 1-dimensional audio signal. Right: corresponding log-Mel spectrogram. Figure source:
# <a href="https://ai.googleblog.com/2019/04/specaugment-new-data-augmentation.html">Google SpecAugment Blog</a>.
# </figcaption>

# %% [markdown]
# We'll load the feature extractor from the pre-trained checkpoint with the default values:

# %%
from transformers import WhisperFeatureExtractor

feature_extractor = WhisperFeatureExtractor.from_pretrained("openai/whisper-small")
# Out:
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]

# %% [markdown]
# ### Load WhisperTokenizer

# %% [markdown]
# The Whisper model outputs a sequence of _token ids_. The tokenizer maps each of these token ids to their corresponding text string. For Hindi, we can load the pre-trained tokenizer and use it for fine-tuning without any further modifications. We simply have to
# specify the target language and the task. These arguments inform the
# tokenizer to prefix the language and task tokens to the start of encoded
# label sequences:

# %%
from transformers import WhisperTokenizer

tokenizer = WhisperTokenizer.from_pretrained("openai/whisper-small", language="Italian", task="transcribe")
# Out:
# tokenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]

# %% [markdown]
# ### Combine To Create A WhisperProcessor

# %% [markdown]
# To simplify using the feature extractor and tokenizer, we can _wrap_
# both into a single `WhisperProcessor` class. This processor object
# inherits from the `WhisperFeatureExtractor` and `WhisperProcessor`,
# and can be used on the audio inputs and model predictions as required.
# In doing so, we only need to keep track of two objects during training:
# the `processor` and the `model`:

# %%
from transformers import WhisperProcessor

processor = WhisperProcessor.from_pretrained("openai/whisper-small", language="Italian", task="transcribe")

# %% [markdown]
# ### Prepare Data

# %% [markdown]
# Let's print the first example of the Common Voice dataset to see
# what form the data is in:

# %%
print(common_voice["train"][0])
# Out:
# {'audio': {'path': '/root/.cache/huggingface/datasets/downloads/extracted/60106da21e955b6e07e96f50324737e94220b976ca6f0ecd2ac109997d817997/it_train_0/common_voice_it_20044036.mp3', 'array': array([0.00000000e+00, 7.48224690e-15, 1.49720121e-14, ...,
#        9.15136206e-06, 6.41537281e-06, 2.52001951e-06]), 'sampling_rate': 48000}, 'sentence': "Vennero per questo classificati all'ultimo posto."}

# %% [markdown]
# Since
# our input audio is sampled at 48kHz, we need to _downsample_ it to
# 16kHz prior to passing it to the Whisper feature extractor, 16kHz being the sampling rate expected by the Whisper model.
#
# We'll set the audio inputs to the correct sampling rate using dataset's
# [`cast_column`](https://huggingface.co/docs/datasets/package_reference/main_classes.html?highlight=cast_column#datasets.DatasetDict.cast_column)
# method. This operation does not change the audio in-place,
# but rather signals to `datasets` to resample audio samples _on the fly_ the
# first time that they are loaded:

# %%
from datasets import Audio

common_voice = common_voice.cast_column("audio", Audio(sampling_rate=16000))

# %% [markdown]
# Re-loading the first audio sample in the Common Voice dataset will resample
# it to the desired sampling rate:

# %%
print(common_voice["train"][0])
# Out:
# {'audio': {'path': '/root/.cache/huggingface/datasets/downloads/extracted/60106da21e955b6e07e96f50324737e94220b976ca6f0ecd2ac109997d817997/it_train_0/common_voice_it_20044036.mp3', 'array': array([-1.81898940e-12,  5.45696821e-12, -7.27595761e-12, ...,
#        -7.20581738e-07,  7.65260484e-06,  1.14752838e-05]), 'sampling_rate': 16000}, 'sentence': "Vennero per questo classificati all'ultimo posto."}

# %% [markdown]
# Now we can write a function to prepare our data ready for the model:
# 1. We load and resample the audio data by calling `batch["audio"]`. As explained above, 🤗 Datasets performs any necessary resampling operations on the fly.
# 2. We use the feature extractor to compute the log-Mel spectrogram input features from our 1-dimensional audio array.
# 3. We encode the transcriptions to label ids through the use of the tokenizer.

# %%
def prepare_dataset(batch):
    # load and resample audio data from 48 to 16kHz
    audio = batch["audio"]

    # compute log-Mel input features from input audio array
    batch["input_features"] = feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features[0]

    # encode target text to label ids
    batch["labels"] = tokenizer(batch["sentence"]).input_ids
    return batch

# %% [markdown]
# We can apply the data preparation function to all of our training examples using dataset's `.map` method. The argument `num_proc` specifies how many CPU cores to use. Setting `num_proc` > 1 will enable multiprocessing. If the `.map` method hangs with multiprocessing, set `num_proc=1` and process the dataset sequentially.

# %%
common_voice = common_voice.map(prepare_dataset, remove_columns=common_voice.column_names["train"], num_proc=2)
# Out:
# Map (num_proc=2):   0%|          | 0/15261 [00:00<?, ? examples/s]
# DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
# DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
# Map (num_proc=2):   0%|          | 0/1500 [00:00<?, ? examples/s]
# DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
# DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz

# %%
common_voice.save_to_disk("common_voice")
# Out:
# Saving the dataset (0/30 shards):   0%|          | 0/15261 [00:00<?, ? examples/s]
# Saving the dataset (0/3 shards):   0%|          | 0/1500 [00:00<?, ? examples/s]

# %%
import os
print(os.getcwd())
print(os.listdir("./common_voice/"))
print(os.listdir("./common_voice/train"))
print(os.listdir("./common_voice/test"))
# Out:
# /content
# ['train', 'dataset_dict.json', 'test']
# ['data-00012-of-00030.arrow', 'data-00020-of-00030.arrow', 'data-00019-of-00030.arrow', 'data-00028-of-00030.arrow', 'dataset_info.json', 'data-00029-of-00030.arrow', 'data-00023-of-00030.arrow', 'data-00026-of-00030.arrow', 'state.json', 'data-00018-of-00030.arrow', 'data-00011-of-00030.arrow', 'data-00005-of-00030.arrow', 'data-00014-of-00030.arrow', 'data-00004-of-00030.arrow', 'data-00027-of-00030.arrow', 'data-00025-of-00030.arrow', 'data-00010-of-00030.arrow', 'data-00003-of-00030.arrow', 'data-00009-of-00030.arrow', 'data-00002-of-00030.arrow', 'data-00017-of-00030.arrow', 'data-00022-of-00030.arrow', 'data-00001-of-00030.arrow', 'data-00008-of-00030.arrow', 'data-00013-of-00030.arrow', 'data-00021-of-00030.arrow', 'data-00015-of-00030.arrow', 'data-00016-of-00030.arrow', 'data-00006-of-00030.arrow', 'data-00024-of-00030.arrow', 'data-00007-of-00030.arrow', 'data-00000-of-00030.arrow']
# ['data-00001-of-00003.arrow', 'dataset_info.json', 'state.json', 'data-00000-of-00003.arrow', 'data-00002-of-00003.arrow']

# %%
def get_dir_size(path='/common_voice/train'):
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total
sz = get_dir_size(path="./common_voice/")
print(sz)
# Out:
# 16099388974

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !zip -r /content/common_voice.zip /content/common_voice
# Out:
#   adding: content/common_voice/ (stored 0%)
#   adding: content/common_voice/train/ (stored 0%)
#   adding: content/common_voice/train/data-00012-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/data-00020-of-00030.arrow (deflated 87%)
#   adding: content/common_voice/train/data-00019-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/data-00028-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/dataset_info.json (deflated 51%)
#   adding: content/common_voice/train/data-00029-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/data-00023-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/data-00026-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/state.json (deflated 88%)
#   adding: content/common_voice/train/data-00018-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/data-00011-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/data-00005-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/data-00014-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/data-00004-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/data-00027-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/data-00025-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/data-00010-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/data-00003-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/data-00009-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/data-00002-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/data-00017-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/data-00022-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/data-00001-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/data-00008-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/data-00013-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/data-00021-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/data-00015-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/data-00016-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/data-00006-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/data-00024-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/train/data-00007-of-00030.arrow (deflated 86%)
#   adding: content/common_voice/train/data-00000-of-00030.arrow (deflated 85%)
#   adding: content/common_voice/dataset_dict.json (stored 0%)
#   adding: content/common_voice/test/ (stored 0%)
#   adding: content/common_voice/test/data-00001-of-00003.arrow (deflated 85%)
#   adding: content/common_voice/test/dataset_info.json (deflated 51%)
#   adding: content/common_voice/test/state.json (deflated 55%)
#   adding: content/common_voice/test/data-00000-of-00003.arrow (deflated 84%)
#   adding: content/common_voice/test/data-00002-of-00003.arrow (deflated 84%)

# %%
# !rm -r /content/drive/MyDrive/common_voice.zip
import shutil
shutil.move("/content/common_voice.zip", "/content/drive/MyDrive")
# Out:
# '/content/drive/MyDrive/common_voice.zip'

# %% [markdown]
# ## Training and Evaluation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /Users/gabrielemorello/miniforge3/envs/scalable/lib/python3.10/site-packages/google/colab/data_table.py:30: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   from IPython.utils import traitlets as _traitlets
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/google/colab/__init__.py:26
#      24 from google.colab import _tensorflow_magics
#      25 from google.colab import auth
# ---> 26 from google.colab import data_table
#      27 from google.colab import drive
#      28 from google.colab import files
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/google/colab/data_table.py:166
#     149       columns_and_types.append((column_type, str(header_formatters[i](column))))
#     151     return """
#     152       import "{gviz_url}";
#     153
#    (...)
#     162         columns=_json.dumps(columns_and_types),
#     163         num_rows_per_page=self._num_rows_per_page)
# --> 166 class _JavascriptModuleFormatter(_IPython.core.formatters.BaseFormatter):
#     167   format_type = _traitlets.Unicode(_JAVASCRIPT_MODULE_MIME_TYPE)
#     168   print_method = _traitlets.ObjectName('_repr_javascript_module_')
#
# File ~/miniforge3/envs/scalable/lib/python3.10/site-packages/google/colab/data_table.py:167, in _JavascriptModuleFormatter()
#     166 class _JavascriptModuleFormatter(_IPython.core.formatters.BaseFormatter):
# --> 167   format_type = _traitlets.Unicode(_JAVASCRIPT_MODULE_MIME_TYPE)
#     168   print_method = _traitlets.ObjectName('_repr_javascript_module_')
#
# AttributeError: module 'IPython.utils.traitlets' has no attribute 'Unicode'

# %%
import os
os.mkdir("/content/common_voice")

# %%
import zipfile
zip = zipfile.ZipFile("/content/drive/MyDrive/common_voice.zip")
zip.extractall("/content/common_voice")

# %%
from datasets import load_dataset, DatasetDict

common_voice = DatasetDict()

common_voice = DatasetDict.load_from_disk("/content/common_voice/content/common_voice")

# %%
common_voice

# %% [markdown]
# Now that we've prepared our data, we're ready to dive into the training pipeline.
# The [🤗 Trainer](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer)
# will do much of the heavy lifting for us. All we have to do is:
#
# - Define a data collator: the data collator takes our pre-processed data and prepares PyTorch tensors ready for the model.
#
# - Evaluation metrics: during evaluation, we want to evaluate the model using the [word error rate (WER)](https://huggingface.co/metrics/wer) metric. We need to define a `compute_metrics` function that handles this computation.
#
# - Load a pre-trained checkpoint: we need to load a pre-trained checkpoint and configure it correctly for training.
#
# - Define the training configuration: this will be used by the 🤗 Trainer to define the training schedule.
#
# Once we've fine-tuned the model, we will evaluate it on the test data to verify that we have correctly trained it
# to transcribe speech in Hindi.

# %% [markdown]
# ### Define a Data Collator

# %% [markdown]
# The data collator for a sequence-to-sequence speech model is unique in the sense that it
# treats the `input_features` and `labels` independently: the  `input_features` must be
# handled by the feature extractor and the `labels` by the tokenizer.
#
# The `input_features` are already padded to 30s and converted to a log-Mel spectrogram
# of fixed dimension by action of the feature extractor, so all we have to do is convert the `input_features`
# to batched PyTorch tensors. We do this using the feature extractor's `.pad` method with `return_tensors=pt`.
#
# The `labels` on the other hand are un-padded. We first pad the sequences
# to the maximum length in the batch using the tokenizer's `.pad` method. The padding tokens
# are then replaced by `-100` so that these tokens are **not** taken into account when
# computing the loss. We then cut the BOS token from the start of the label sequence as we
# append it later during training.
#
# We can leverage the `WhisperProcessor` we defined earlier to perform both the
# feature extractor and the tokenizer operations:

# %%
import torch

from dataclasses import dataclass
from typing import Any, Dict, List, Union

@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        # pad the labels to max length
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %% [markdown]
# Let's initialise the data collator we've just defined:

# %%
from transformers import WhisperProcessor

processor = WhisperProcessor.from_pretrained("openai/whisper-small", language="Italian", task="transcribe")
# Out:
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %% [markdown]
# ### Evaluation Metrics

# %% [markdown]
# We'll use the word error rate (WER) metric, the 'de-facto' metric for assessing
# ASR systems. For more information, refer to the WER [docs](https://huggingface.co/metrics/wer). We'll load the WER metric from 🤗 Evaluate:

# %%
import evaluate

metric = evaluate.load("wer")
# Out:
# Downloading builder script:   0%|          | 0.00/4.49k [00:00<?, ?B/s]

# %% [markdown]
# We then simply have to define a function that takes our model
# predictions and returns the WER metric. This function, called
# `compute_metrics`, first replaces `-100` with the `pad_token_id`
# in the `label_ids` (undoing the step we applied in the
# data collator to ignore padded tokens correctly in the loss).
# It then decodes the predicted and label ids to strings. Finally,
# it computes the WER between the predictions and reference labels:

# %%
def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # replace -100 with the pad_token_id
    label_ids[label_ids == -100] = tokenizer.pad_token_id

    # we do not want to group tokens when computing the metrics
    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)

    wer = 100 * metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %% [markdown]
# ### Load a Pre-Trained Checkpoint

# %% [markdown]
# Now let's load the pre-trained Whisper `small` checkpoint. Again, this
# is trivial through use of 🤗 Transformers!

# %%
from transformers import WhisperForConditionalGeneration

model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-small")
# Out:
# config.json:   0%|          | 0.00/1.97k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/967M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.84k [00:00<?, ?B/s]

# %% [markdown]
# Override generation arguments - no tokens are forced as decoder outputs (see [`forced_decoder_ids`](https://huggingface.co/docs/transformers/main_classes/text_generation#transformers.generation_utils.GenerationMixin.generate.forced_decoder_ids)), no tokens are suppressed during generation (see [`suppress_tokens`](https://huggingface.co/docs/transformers/main_classes/text_generation#transformers.generation_utils.GenerationMixin.generate.suppress_tokens)):

# %%
model.config.forced_decoder_ids = None
model.config.suppress_tokens = []

# %% [markdown]
# ### Define the Training Configuration

# %% [markdown]
# In the final step, we define all the parameters related to training. For more detail on the training arguments, refer to the Seq2SeqTrainingArguments [docs](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.Seq2SeqTrainingArguments).

# %%
! pip uninstall transformers
! pip install -U accelerate
! pip install -U transformers
# Out:
# Found existing installation: transformers 4.35.2
# Uninstalling transformers-4.35.2:
#   Would remove:
#     /usr/local/bin/transformers-cli
#     /usr/local/lib/python3.10/dist-packages/transformers-4.35.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/transformers/*
# Proceed (Y/n)?
#
#   Successfully uninstalled transformers-4.35.2
# Collecting accelerate
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.25.0
# Collecting transformers
#   Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 23.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Installing collected packages: transformers
# Successfully installed transformers-4.35.2

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    num_train_epochs=1,
    output_dir="./whisper-small-it",  # change to a repo name of your choice
    per_device_train_batch_size=16,
    gradient_accumulation_steps=1,  # increase by 2x for every 2x decrease in batch size
    learning_rate=1e-5,
    warmup_steps=500,
    gradient_checkpointing=True,
    fp16=True,
    evaluation_strategy="steps",
    save_strategy="steps",
    per_device_eval_batch_size=8,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=100,
    eval_steps=100,
    save_total_limit=2,
    logging_steps=25,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=True,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-ba96ce683d72> in <cell line: 3>()
#       1 from transformers import Seq2SeqTrainingArguments
#       2
# ----> 3 training_args = Seq2SeqTrainingArguments(
#       4     num_train_epochs=1,
#       5     output_dir="./whisper-small-it",  # change to a repo name of your choice
#
# /usr/local/lib/python3.10/dist-packages/transformers/training_args_seq2seq.py in __init__(self, output_dir, overwrite_output_dir, do_train, do_eval, do_predict, evaluation_strategy, prediction_loss_only, per_device_train_batch_size, per_device_eval_batch_size, per_gpu_train_batch_size, per_gpu_eval_batch_size, gradient_accumulation_steps, eval_accumulation_steps, eval_delay, learning_rate, weight_decay, adam_beta1, adam_beta2, adam_epsilon, max_grad_norm, num_train_epochs, max_steps, lr_scheduler_type, warmup_ratio, warmup_steps, log_level, log_level_replica, log_on_each_node, logging_dir, logging_strategy, logging_first_step, logging_steps, logging_nan_inf_filter, save_strategy, save_steps, save_total_limit, save_safetensors, save_on_each_node, no_cuda, use_cpu, use_mps_device, seed, data_seed, jit_mode_eval, use_ipex, bf16, fp16, fp16_opt_level, half_precision_backend, bf16_full_eval, fp16_full_eval, tf32, local_rank, ddp_backend, tpu_num_cores, tpu_metrics_debug, debug, dataloader_drop_last, eval_steps, dataloader_num_workers, past_index, run_name, disable_tqdm, remove_unused_columns, label_names, load_best_model_at_end, metric_for_best_model, greater_is_better, ignore_data_skip, fsdp, fsdp_min_num_params, fsdp_config, fsdp_transformer_layer_cls_to_wrap, deepspeed, label_smoothing_factor, optim, optim_args, adafactor, group_by_length, length_column_name, report_to, ddp_find_unused_parameters, ddp_bucket_cap_mb, ddp_broadcast_buffers, dataloader_...
#
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py in __post_init__(self)
#    1446             and (self.fp16 or self.fp16_full_eval)
#    1447         ):
# -> 1448             raise ValueError(
#    1449                 "FP16 Mixed precision training with AMP or APEX (`--fp16`) and FP16 half precision evaluation"
#    1450                 " (`--fp16_full_eval`) can only be used on CUDA or NPU devices or certain XPU devices (with IPEX)."
#
# ValueError: FP16 Mixed precision training with AMP or APEX (`--fp16`) and FP16 half precision evaluation (`--fp16_full_eval`) can only be used on CUDA or NPU devices or certain XPU devices (with IPEX).

# %% [markdown]
# **Note**: if one does not want to upload the model checkpoints to the Hub,
# set `push_to_hub=False`.

# %% [markdown]
# We can forward the training arguments to the 🤗 Trainer along with our model,
# dataset, data collator and `compute_metrics` function:

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=common_voice["train"],
    eval_dataset=common_voice["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor.feature_extractor,
)

# %% [markdown]
# We'll save the processor object once before starting training. Since the processor is not trainable, it won't change over the course of training:

# %%
processor.save_pretrained(training_args.output_dir)

# %% [markdown]
# ### Training

# %% [markdown]
# Training will take approximately 5-10 hours depending on your GPU or the one
# allocated to this Google Colab. If using this Google Colab directly to
# fine-tune a Whisper model, you should make sure that training isn't
# interrupted due to inactivity. A simple workaround to prevent this is
# to paste the following code into the console of this tab (_right mouse click_
# -> _inspect_ -> _Console tab_ -> _insert code_).

# %% [markdown]
# ```javascript
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }
# setInterval(ConnectButton, 60000);
# ```

# %% [markdown]
# The peak GPU memory for the given training configuration is approximately 15.8GB.
# Depending on the GPU allocated to the Google Colab, it is possible that you will encounter a CUDA `"out-of-memory"` error when you launch training.
# In this case, you can reduce the `per_device_train_batch_size` incrementally by factors of 2
# and employ [`gradient_accumulation_steps`](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.Seq2SeqTrainingArguments.gradient_accumulation_steps)
# to compensate.
#
# To launch training, simply execute:

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
#     <div>
#
#       <progress value='601' max='954' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [601/954 3:17:35 < 1:56:26, 0.05 it/s, Epoch 0.63/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>1.388700</td>
#       <td>1.296234</td>
#       <td>177.932612</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.743500</td>
#       <td>0.869978</td>
#       <td>115.356351</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.329400</td>
#       <td>0.446965</td>
#       <td>46.512757</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.276700</td>
#       <td>0.425983</td>
#       <td>82.362729</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.268100</td>
#       <td>0.419344</td>
#       <td>71.325568</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='96' max='188' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 96/188 11:42 < 11:20, 0.14 it/s]
#     </div>
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(

# %%
trainer.train(resume_from_checkpoint=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-76cea7b55f9a> in <cell line: 1>()
# ----> 1 trainer.train(resume_from_checkpoint=True)
#
# NameError: name 'trainer' is not defined

# %% [markdown]
# Our best WER is 32.0% - not bad for 8h of training data! We can submit our checkpoint to the [`hf-speech-bench`](https://huggingface.co/spaces/huggingface/hf-speech-bench) on push by setting the appropriate key-word arguments (kwargs):

# %%
kwargs = {
    "dataset_tags": "mozilla-foundation/common_voice_11_0",
    "dataset": "Common Voice 11.0",  # a 'pretty' name for the training dataset
    "dataset_args": "config: it, split: test",
    "language": "it",
    "model_name": "Whisper Small It",  # a 'pretty' name for our model
    "finetuned_from": "openai/whisper-small",
    "tasks": "automatic-speech-recognition",
    "tags": "hf-asr-leaderboard",
}

# %% [markdown]
# The training results can now be uploaded to the Hub. To do so, execute the `push_to_hub` command and save the preprocessor object we created:

# %%
trainer.push_to_hub(**kwargs)

# %% [markdown]
# ## Building a Demo

# %% [markdown]
# Now that we've fine-tuned our model we can build a demo to show
# off its ASR capabilities! We'll make use of 🤗 Transformers
# `pipeline`, which will take care of the entire ASR pipeline,
# right from pre-processing the audio inputs to decoding the
# model predictions.
#
# Running the example below will generate a Gradio demo where we
# can record speech through the microphone of our computer and input it to
# our fine-tuned Whisper model to transcribe the corresponding text:

# %%
from transformers import pipeline
import gradio as gr

pipe = pipeline(model="jdowling/whisper-small-hi")  # change to "your-username/the-name-you-picked"

def transcribe(audio):
    text = pipe(audio)["text"]
    return text

iface = gr.Interface(
    fn=transcribe,
    inputs=gr.Audio(source="microphone", type="filepath"),
    outputs="text",
    title="Whisper Small Italian",
    description="Realtime demo for Swedish speech recognition using a fine-tuned Whisper small model.",
)

iface.launch()

# %% [markdown]
# ## Closing Remarks

# %% [markdown]
# In this blog, we covered a step-by-step guide on fine-tuning Whisper for multilingual ASR
# using 🤗 Datasets, Transformers and the Hugging Face Hub. For more details on the Whisper model, the Common Voice dataset and the theory behind fine-tuning, refere to the accompanying [blog post](https://huggingface.co/blog/fine-tune-whisper). If you're interested in fine-tuning other
# Transformers models, both for English and multilingual ASR, be sure to check out the
# examples scripts at [examples/pytorch/speech-recognition](https://github.com/huggingface/transformers/tree/main/examples/pytorch/speech-recognition).
